# %%
import geopandas as gpd
from shapely.geometry import Point
import pandas as pd
import matplotlib.pyplot as plt

# %%
point = Point(36.8219, -1.2921)
# Create a GeoDataFrame with the point using WGS84
gdf_wgs84 = gpd.GeoDataFrame({
    'city': ['Nairobi']},
    geometry=[point],
    crs='EPSG:4326'  # WGS84
)

# %%
gdf_wgs84
# Out:
#       city                 geometry
# 0  Nairobi  POINT (36.8219 -1.2921)

# %%
# Reproject to UTM Zone 37N (EPSG:32637)
gdf_utm = gdf_wgs84.to_crs('EPSG:32637')  # UTM zone 37N

# %%
gdf_utm
# Out:
#       city                        geometry
# 0  Nairobi  POINT (257634.502 -142920.034)

# %%
gdf_utm.crs
# Out:
# <Projected CRS: EPSG:32637>
# Name: WGS 84 / UTM zone 37N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 36°E and 42°E, northern hemisphere between equator and 84°N, onshore and offshore. Djibouti. Egypt. Eritrea. Ethiopia. Georgia. Iraq. Jordan. Kenya. Lebanon. Russian Federation. Saudi Arabia. Somalia. Sudan. Syria. Türkiye (Turkey). Ukraine.
# - bounds: (36.0, 0.0, 42.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 37N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Plot the point in both coordinate systems
fix, ax = plt.subplots(1, 2, figsize=(20, 5))
gdf_wgs84.plot(ax=ax[0], color='blue')
ax[0].set_title('WGS84 Coordinate System')
ax[0].set_xlabel('Longitude')
ax[0].set_ylabel('Latitude')
gdf_utm.plot(ax=ax[1], color='red')
ax[1].set_title('UTM Zone 37N Coordinate System')
ax[1].set_xlabel('Easting')
ax[1].set_ylabel('Northing')
plt.show()
